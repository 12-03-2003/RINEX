# %% [markdown]
# <a href="https://colab.research.google.com/github/12-03-2003/RINEX/blob/main/miniproject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''  
NAME           : DEEKSHA R SHETTY
COLLEGE        : DAYANANDA SAGAR UNIVERSITY
BRANCH         : AEROSPACE ENGINEERING
YEAR           : FIRST YEAR
DATASET SOURCE : KAGGLE
MAIL ID        : deekshashetty082@gmail.com
'''

# %%
#Creating DataFrame from dataset
import pandas as pd
df = pd.read_csv('/content/covid 19 CountryWise.csv')
df
# Out:
#                                    Country           Region  Total Cases  \
# 0                 United States of America         Americas     94152573
# 1                                    India  South-East Asia     44516479
# 2                                   Brazil         Americas     34544377
# 3                                   France           Europe     33766090
# 4                                  Germany           Europe     32604993
# ..                                     ...              ...          ...
# 232                       Pitcairn Islands  Western Pacific            4
# 233  Democratic People's Republic of Korea  South-East Asia            0
# 234                           Saint Helena           Africa            0
# 235                                Tokelau  Western Pacific            0
# 236                           Turkmenistan           Europe            0
#
#      Total Cases per 100k pop  New Cases (7 days)  \
# ...

# %%
#to extract information from DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           237 non-null    object
#  1   Region                            237 non-null    object
#  2   Total Cases                       237 non-null    int64
#  3   Total Cases per 100k pop          236 non-null    float64
#  4   New Cases (7 days)                237 non-null    int64
#  5   New Cases per 100k pop (7 days)   236 non-null    float64
#  6   New Cases (24 hours)              237 non-null    int64
#  7   Total Deaths                      237 non-null    int64
#  8   Total Deaths per 100k pop         236 non-null    float64
#  9   New Deaths (7 days)               237 non-null    int64
#  10  New Deaths per 100k pop (7 days)  236 non-null    float64
# ...

# %%
#to find the number of rows and columns, this DataFrame has 237 rows and 12 columns
df.shape
# Out:
# (237, 12)

# %%
#to find total number of elements in the DataFrame
df.size
# Out:
# 2844

# %%
#to find the missing values and null values
df.isnull().sum()
# Out:
# Country                             0
# Region                              0
# Total Cases                         0
# Total Cases per 100k pop            1
# New Cases (7 days)                  0
# New Cases per 100k pop (7 days)     1
# New Cases (24 hours)                0
# Total Deaths                        0
# Total Deaths per 100k pop           1
# New Deaths (7 days)                 0
# New Deaths per 100k pop (7 days)    1
# New Deaths (24 hours)               0
# dtype: int64

# %%
# Visualization

# %%
#1.to find the total number of people recovered in each country using visualization technique
import matplotlib.pyplot as plt
recovery=df['Total Cases']-df['Total Deaths']
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],recovery)
# Out:
# <BarContainer object of 237 artists>

# %%
#2.To find maximum number of cases in a country
df['Total Cases'].max()
# Out:
# 94152573

# %%
#3.To find the maximum death in all countries using visualization technique
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],df['Total Deaths'])
# Out:
# <BarContainer object of 237 artists>

# %%
#4.To find the total number of cases reported in all countries using visualization technique
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],df['Total Cases'])
# Out:
# <BarContainer object of 237 artists>

# %%
#5.To find the maximum number of cases reported in a country in a day using visualization technique
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],df['New Cases (24 hours)'])
# Out:
# <BarContainer object of 237 artists>

# %%
#6.To find maximum number of deaths in a country
df['Total Deaths'].max()
# Out:
# 1040506

# %%
#7.To find the maximum number of new cases reported in a country in a week using visualization technique
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],df['New Cases (7 days)'])
# Out:
# <BarContainer object of 237 artists>

# %%
#8.to find the total number of people recovered in each country in a week using visualization technique
import matplotlib.pyplot as plt
recovery=df['New Cases (7 days)']-df['New Deaths (7 days)']
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],recovery)
# Out:
# <BarContainer object of 237 artists>

# %%
#9.To find the maximum number of deaths reported in a country in a day using visualization technique
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],df['New Deaths (24 hours)'])
# Out:
# <BarContainer object of 237 artists>

# %%
#10.To find the total number of deaths in 1 million reported in all countries in a week using visualization technique
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],df['New Deaths per 100k pop (7 days)'])
# Out:
# <BarContainer object of 237 artists>

# %%
#11.To find the total number of cases in 1 million reported in all countries in a week using visualization technique
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],df['New Cases per 100k pop (7 days)'])
# Out:
# <BarContainer object of 237 artists>

# %%
#12.to find the total number of people recovered in each country in 1 milion population using visualization technique
import matplotlib.pyplot as plt
recovery=df['Total Cases per 100k pop']-df['Total Deaths per 100k pop']
plt.figure(figsize=(50,20))
plt.xticks(rotation='vertical')
plt.bar(df['Country'],recovery)
# Out:
# <BarContainer object of 237 artists>
